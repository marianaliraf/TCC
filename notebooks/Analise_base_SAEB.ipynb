# %% [markdown]
# # Análise dos dados das variáveis relacionadas ao IDEB
#
# O notebook contém experimentos com essas variáveis. São utilizadas duas bases de dados:<br>
# - Váriáveis derivadas do SAEB (informações socioeconômicas)<br>
# - Variáveis com informações das escolas e professores<br>

# %%
import pandas as pd
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression, mutual_info_regression, f_classif
from sklearn.preprocessing import LabelEncoder
import numpy as np
from numpy import array

# %% [markdown]
# ## Importando bases de dados

# %%
#Importando variáveis derivadas do SAEB

dados_pessoais = pd.read_csv('C:/Users/maril/Documents/ufs/TCC e Pesquisa IDEB/variaveis_derivadas_2.0.csv')

dados_pessoais.set_index('ID_ESCOLA', inplace=True)

# %% [markdown]
# **Pré-processamento da base de dados pessoais**

# %%
#Função que verifica se o ID de uma escola é inválido
#Segundo o Dicionário de Dados da base o SAEB 6 - Os códigos dos Municípios e 
#das Escolas que começam com o dígito "6" são máscaras, isto é, são códigos fictícios.
def retira_id_ficticio(id_escola):
    if id_escola[0] == "6":
        return True
    else:
        return False

# %%
#Se retirou as escolas fictícias
for escola in dados_pessoais.index:
    if (retira_id_ficticio(str(escola))):
        dados_pessoais.drop(escola, inplace=True)
        

dados_pessoais
# Out:
#            ID_PROVA_BRASIL  ID_REGIAO  ID_UF  ID_MUNICIPIO  ID_AREA  \
# ID_ESCOLA
# 28012631              2017          2     28       2800100        2
# 28017846              2017          2     28       2800308        1
# 28017854              2017          2     28       2800308        1
# 28018400              2017          2     28       2800308        1
# 28018435              2017          2     28       2800308        1
# ...                    ...        ...    ...           ...      ...
# 28009398              2017          2     28       2807105        2
# 28009487              2017          2     28       2807105        2
# 28014839              2017          2     28       2807204        2
# 28010132              2017          2     28       2807402        2
# 28028562              2017          2     28       2807600        2
#
#            ID_DEPENDENCIA_ADM  ID_LOCALIZACAO  TX_RESP_Q001_A  TX_RESP_Q001_B  \
# ID_ESCOLA
# 28012631                    2               1              12               6
# 28017846                    2               1              21              20
# 28017854                    2               1              39              62
# 28018400                    2               1              36              36
# 28018435                    2               1              56              79
# ...                       ...             ...             ...             ...
# 28009398                    2               1             106             186
# 28009487                    2               2              18              23
# 28014839                    2               1              31              42
# 28010132                    2               1              62              76
# 28028562                    2               1              33              68
#
#            TX_RESP_Q020_A  ...  TX_RESP_Q003_B  TX_RESP_Q003_C  \
# ID_ESCOLA                  ...
# 28012631               15  ...               2               3
# 28017846               37  ...               4              10
# 28017854               93  ...               7               9
# 28018400               71  ...               6              10
# 28018435              124  ...              13              10
# ...                   ...  ...             ...             ...
# 28009398              253  ...              28              37
# 28009487               32  ...               3               1
# 28014839               68  ...               8               5
# 28010132              110  ...               5              16
# 28028562               80  ...               4               4
#
#            TX_RESP_Q003_D  TX_RESP_Q003_E  TX_RESP_Q003_F  TX_RESP_Q003_G  \
# ID_ESCOLA
# 28012631                1               1               0               0
# 28017846                2               7               4               1
# 28017854                4              10              13               5
# 28018400                8               8               4               4
# 28018435               14              21              11              10
# ...                   ...             ...             ...             ...
# 28009398               24              26              21              24
# 28009487                4               6               3               7
# 28014839                5              11               5               8
# 28010132               13              17               9              10
# 28028562               15              12              10               6
#
#            TX_RESP_Q003_H  TX_RESP_Q003_I  TX_RESP_Q003_J  TX_RESP_Q003_L
# ID_ESCOLA
# 28012631                3               3               2               1
# 28017846                4               3               3               1
# 28017854               15              11               5              10
# 28018400                5               3               6               7
# 28018435               11              11               7              18
# ...                   ...             ...             ...             ...
# 28009398               25              18              22              29
# 28009487                2               1               4               4
# 28014839                6               5               8               5
# 28010132               13              12              15               6
# 28028562                6               8               9              12
#
# [77 rows x 234 columns]

# %%
#Importando variáveis com informações das escolas e professores
dados_escola = pd.read_csv('C:/Users/maril/Documents/ufs/TCC e Pesquisa IDEB/ESCOLAS2017-SE.csv')

dados_escola.set_index('CO_ENTIDADE', inplace=True)

dados_escola
# Out:
#              NU_ANO_CENSO                                        NO_ENTIDADE  \
# CO_ENTIDADE
# 28017943             2017                               COLEGIO AMADEUS LTDA
# 28010124             2017  ESCOLA DE EDUCACAO BASICA MONSENHOR JOSE DE SO...
# 28018052             2017                   COLEGIO SANTANNA DE SERGIPE LTDA
# 28032497             2017                                   COLEGIO NOTA DEZ
# 28017773             2017                              COL AMERICANO BATISTA
# ...                   ...                                                ...
# 28022033             2017        COLEGIO ESTADUAL CLEONICE SOARES DA FONSECA
# 28005759             2017                COLEGIO ESTADUAL EMILIANO GUIMARAES
# 28018940             2017                     COLEGIO ESTADUAL SANTOS DUMONT
# 28025903             2017               COLEGIO ESTADUAL COMENDADOR CALAZANS
# 28029577             2017  COLEGIO ESTADUAL PREFEITO JOALDO LIMA DE CARVALHO
#
#              CO_ORGAO_REGIONAL  TP_SITUACAO_FUNCIONAMENTO  \
# CO_ENTIDADE
# 28017943                   0.0                          1
# 28010124                   2.0                          1
# 28018052                   0.0                          1
# 28032497                   3.0                          1
# 28017773                   0.0                          1
# ...                        ...                        ...
# 28022033                   2.0                          1
# 28005759                   6.0                          1
# 28018940                   0.0                          1
# 28025903                   1.0                          1
# 28029577                   1.0                          1
#
#             DT_ANO_LETIVO_INICIO DT_ANO_LETIVO_TERMINO  CO_REGIAO  \
# CO_ENTIDADE
# 28017943              16/01/2017            24/11/2017          2
# 28010124              01/02/2017            08/12/2017          2
# 28018052              09/01/2017            01/12/2017          2
# 28032497              23/01/2017            15/12/2017          2
# 28017773              16/01/2017            01/12/2017          2
# ...                          ...                   ...        ...
# 28022033              20/02/2017            21/12/2017          2
# 28005759              27/03/2017            16/01/2018          2
# 28018940              02/05/2017            21/03/2018          2
# 28025903              13/03/2017            05/02/2018          2
# 28029577              06/03/2017            29/01/2018          2
#
#              CO_MESORREGIAO  CO_MICRORREGIAO  CO_UF  ...  QtdeDocentesMonit  \
# CO_ENTIDADE                                          ...
# 28017943               2803            28011     28  ...                  0
# 28010124               2802            28005     28  ...                  0
# 28018052               2803            28011     28  ...                  0
# 28032497               2802            28004     28  ...                  0
# 28017773               2803            28011     28  ...                  0
# ...                     ...              ...    ...  ...                ...
# 28022033               2803            28012     28  ...                  0
# 28005759               2802            28003     28  ...                  0
# 28018940               2803            28011     28  ...                  0
# 28025903               2803            28013     28  ...                  0
# 28029577               2803            28012     28  ...                  0
#
#              QtdeDocentesEfetivos  QtdeDocentesTempo  QtdeDocentesTerceir  \
# CO_ENTIDADE
# 28017943                        0                  0                    0
# 28010124                        0                  0                    0
# 28018052                        0                  0                    0
# 28032497                        0                  0                    0
# 28017773                        0                  0                    0
# ...                           ...                ...                  ...
# 28022033                       27                  0                    0
# 28005759                       14                  2                    0
# 28018940                       30                  0                    0
# 28025903                       15                  1                    0
# 28029577                       24                  3                    0
#
#              QtdeDocentesCLT  QtdeDocentesTotal  QtdeAlunosTotal  \
# CO_ENTIDADE
# 28017943                  45                 45              345
# 28010124                  24                 24              103
# 28018052                  17                 17               89
# 28032497                  11                 11               21
# 28017773                  22                 22              152
# ...                      ...                ...              ...
# 28022033                   0                 27              326
# 28005759                   0                 16               85
# 28018940                   0                 30              257
# 28025903                   0                 16              184
# 28029577                   0                 27              472
#
#              QtdeTurmasProf  RelAlunProf  Ideb-2017
# CO_ENTIDADE
# 28017943                 45            7        6.9
# 28010124                 24            4        6.6
# 28018052                 17            5        6.4
# 28032497                 11            1        6.1
# 28017773                 22            6        5.8
# ...                     ...          ...        ...
# 28022033                 27           12        4.0
# 28005759                 16            5        3.0
# 28018940                 30            8        3.0
# 28025903                 16           11        3.0
# 28029577                 27           17        3.0
#
# [96 rows x 185 columns]

# %% [markdown]
# #### Pré-processamento da base das escolas

# %%
#Retirando valores ausentes
filteredColumns = dados_escola.dtypes[dados_escola.dtypes == np.float64]

listOfColumnNames = list(filteredColumns.index)

# retorna o número de valores ausentes para cada coluna
dados_escola[listOfColumnNames].isnull().sum()
# Out:
# CO_ORGAO_REGIONAL                 1
# TP_CATEGORIA_ESCOLA_PRIVADA      76
# IN_CONVENIADA_PP                 76
# TP_CONVENIO_PODER_PUBLICO        96
# IN_MANT_ESCOLA_PRIVADA_EMP       76
# IN_MANT_ESCOLA_PRIVADA_ONG       76
# IN_MANT_ESCOLA_PRIVADA_SIND      76
# IN_MANT_ESCOLA_PRIVADA_SIST_S    76
# IN_MANT_ESCOLA_PRIVADA_S_FINS    76
# CO_ESCOLA_SEDE_VINCULADA         96
# CO_IES_OFERTANTE                 96
# TP_OCUPACAO_PREDIO_ESCOLAR        1
# TP_OCUPACAO_GALPAO               96
# IN_PREDIO_COMPARTILHADO           1
# IN_FUNDAMENTAL_CICLOS             3
# TP_INDIGENA_LINGUA               96
# CO_LINGUA_INDIGENA               96
# Ideb-2017                         0
# dtype: int64

# %%
#Retirando colunas que apresentam mais de 70% do valores nulos
dados_escola.dropna(thresh=len(dados_escola)*0.7, axis=1, inplace=True)

#Preenchendo valores ausentes
dados_escola.fillna(-1, inplace=True)

filteredColumns = dados_escola.dtypes[dados_escola.dtypes == np.float64]

listOfColumnNames = list(filteredColumns.index)

# retorna o número de valores ausentes para cada coluna
dados_escola[listOfColumnNames].isnull().sum()
# Out:
# CO_ORGAO_REGIONAL             0
# TP_OCUPACAO_PREDIO_ESCOLAR    0
# IN_PREDIO_COMPARTILHADO       0
# IN_FUNDAMENTAL_CICLOS         0
# Ideb-2017                     0
# dtype: int64

# %%
dados_escola['IN_FUNDAMENTAL_CICLOS'].unique()
# Out:
# array([ 0.,  1., -1.])

# %%
#Colunas categóricas
filteredColumns = dados_escola.dtypes[dados_escola.dtypes == np.object]

listOfColumnNames = list(filteredColumns.index)

dados_escola[listOfColumnNames]
# Out:
#                                                    NO_ENTIDADE  \
# CO_ENTIDADE
# 28017943                                  COLEGIO AMADEUS LTDA
# 28010124     ESCOLA DE EDUCACAO BASICA MONSENHOR JOSE DE SO...
# 28018052                      COLEGIO SANTANNA DE SERGIPE LTDA
# 28032497                                      COLEGIO NOTA DEZ
# 28017773                                 COL AMERICANO BATISTA
# ...                                                        ...
# 28022033           COLEGIO ESTADUAL CLEONICE SOARES DA FONSECA
# 28005759                   COLEGIO ESTADUAL EMILIANO GUIMARAES
# 28018940                        COLEGIO ESTADUAL SANTOS DUMONT
# 28025903                  COLEGIO ESTADUAL COMENDADOR CALAZANS
# 28029577     COLEGIO ESTADUAL PREFEITO JOALDO LIMA DE CARVALHO
#
#             DT_ANO_LETIVO_INICIO DT_ANO_LETIVO_TERMINO
# CO_ENTIDADE
# 28017943              16/01/2017            24/11/2017
# 28010124              01/02/2017            08/12/2017
# 28018052              09/01/2017            01/12/2017
# 28032497              23/01/2017            15/12/2017
# 28017773              16/01/2017            01/12/2017
# ...                          ...                   ...
# 28022033              20/02/2017            21/12/2017
# 28005759              27/03/2017            16/01/2018
# 28018940              02/05/2017            21/03/2018
# 28025903              13/03/2017            05/02/2018
# 28029577              06/03/2017            29/01/2018
#
# [96 rows x 3 columns]

# %%
#Tratando datas, convertendo para timestamp

inicio = pd.to_datetime(dados_escola['DT_ANO_LETIVO_INICIO'], infer_datetime_format = True)
termino = pd.to_datetime(dados_escola['DT_ANO_LETIVO_TERMINO'], infer_datetime_format = True)

dados_escola['DT_ANO_LETIVO_INICIO'] = inicio.values.astype (np.int64)
dados_escola['DT_ANO_LETIVO_TERMINO'] = termino.values.astype (np.int64)

# %%
dados_escola.drop('NO_ENTIDADE', axis=1, inplace=True)

# %% [markdown]
# ### Unindo as bases de dados
#
# Foi realizado join nos dois datasets, nesse momento se percebeu que não existem variáveis escolas particulares na base derivada do SAEB

# %%
dataset = dados_pessoais.join(dados_escola, how="inner")

# %%
dataset
# Out:
#           ID_PROVA_BRASIL  ID_REGIAO  ID_UF  ID_MUNICIPIO  ID_AREA  \
# 28012631             2017          2     28       2800100        2
# 28017846             2017          2     28       2800308        1
# 28017854             2017          2     28       2800308        1
# 28018400             2017          2     28       2800308        1
# 28018435             2017          2     28       2800308        1
# ...                   ...        ...    ...           ...      ...
# 28009398             2017          2     28       2807105        2
# 28009487             2017          2     28       2807105        2
# 28014839             2017          2     28       2807204        2
# 28010132             2017          2     28       2807402        2
# 28028562             2017          2     28       2807600        2
#
#           ID_DEPENDENCIA_ADM  ID_LOCALIZACAO  TX_RESP_Q001_A  TX_RESP_Q001_B  \
# 28012631                   2               1              12               6
# 28017846                   2               1              21              20
# 28017854                   2               1              39              62
# 28018400                   2               1              36              36
# 28018435                   2               1              56              79
# ...                      ...             ...             ...             ...
# 28009398                   2               1             106             186
# 28009487                   2               2              18              23
# 28014839                   2               1              31              42
# 28010132                   2               1              62              76
# 28028562                   2               1              33              68
#
#           TX_RESP_Q020_A  ...  QtdeDocentesMonit  QtdeDocentesEfetivos  \
# 28012631              15  ...                  0                     7
# 28017846              37  ...                  0                    22
# 28017854              93  ...                  0                    32
# 28018400              71  ...                  0                    34
# 28018435             124  ...                  0                    41
# ...                  ...  ...                ...                   ...
# 28009398             253  ...                  0                    46
# 28009487              32  ...                  0                    12
# 28014839              68  ...                  1                    16
# 28010132             110  ...                  0                    27
# 28028562              80  ...                  0                    18
#
#           QtdeDocentesTempo  QtdeDocentesTerceir  QtdeDocentesCLT  \
# 28012631                  1                    0                0
# 28017846                  0                    0                0
# 28017854                  0                    0                0
# 28018400                  0                    0                0
# 28018435                  0                    0                0
# ...                     ...                  ...              ...
# 28009398                  5                    0                0
# 28009487                  1                    0                0
# 28014839                  0                    0                1
# 28010132                  3                    0                0
# 28028562                  4                    0                0
#
#           QtdeDocentesTotal  QtdeAlunosTotal  QtdeTurmasProf  RelAlunProf  \
# 28012631                  8               22               8            2
# 28017846                 22              121              22            5
# 28017854                 32              301              32            9
# 28018400                 34              383              34           11
# 28018435                 41              476              41           11
# ...                     ...              ...             ...          ...
# 28009398                 51              611              51           11
# 28009487                 13              176              13           13
# 28014839                 17              198              17           11
# 28010132                 30              486              30           16
# 28028562                 22              175              22            7
#
#           Ideb-2017
# 28012631        3.1
# 28017846        3.9
# 28017854        2.9
# 28018400        3.9
# 28018435        3.7
# ...             ...
# 28009398        3.5
# 28009487        3.9
# 28014839        3.5
# 28010132        3.5
# 28028562        3.5
#
# [76 rows x 405 columns]

# %%
dataset['ID_DEPENDENCIA_ADM'].unique()
# Out:
# array([2, 1], dtype=int64)

# %%
dataset.to_csv('C:/Users/maril/Documents/ufs/TCC e Pesquisa Ideb/variaveis_derivadas_escola_estudante_2.0.csv')

# %% [markdown]
# ### Discretização dos rótulos, nota do Ideb
#
# **Discretização:** É o processo de transferência de funções contínuas, modelos, variáveis e equações em contrapartes discretas.

# %%
# São três classes média, acima da média e abaixo da média
def discretizacao(ideb, mean_ideb):
    classe = []
    for nota in ideb['Ideb-2017']:
        if (mean_ideb == nota):
            classe.append('média')
        elif (mean_ideb < nota):
            classe.append('acima da média')
        else:
            classe.append('abaixo da média')
    return classe

# %%
#discretizando as notas do Ideb

Ideb = dataset[['Ideb-2017']]

mean_Ideb = round(Ideb.mean(),1)

classe_ideb = discretizacao(Ideb, mean_Ideb['Ideb-2017'])

Ideb.insert(1, 'classe-Ideb', classe_ideb)

Ideb
# Out:
#           Ideb-2017      classe-Ideb
# 28012631        3.1  abaixo da média
# 28017846        3.9   acima da média
# 28017854        2.9  abaixo da média
# 28018400        3.9   acima da média
# 28018435        3.7   acima da média
# ...             ...              ...
# 28009398        3.5   acima da média
# 28009487        3.9   acima da média
# 28014839        3.5   acima da média
# 28010132        3.5   acima da média
# 28028562        3.5   acima da média
#
# [76 rows x 2 columns]

# %%
dados_escola.columns
# Out:
# Index(['NU_ANO_CENSO', 'CO_ORGAO_REGIONAL', 'TP_SITUACAO_FUNCIONAMENTO',
#        'DT_ANO_LETIVO_INICIO', 'DT_ANO_LETIVO_TERMINO', 'CO_REGIAO',
#        'CO_MESORREGIAO', 'CO_MICRORREGIAO', 'CO_UF', 'CO_MUNICIPIO',
#        ...
#        'QtdeDocentesMonit', 'QtdeDocentesEfetivos', 'QtdeDocentesTempo',
#        'QtdeDocentesTerceir', 'QtdeDocentesCLT', 'QtdeDocentesTotal',
#        'QtdeAlunosTotal', 'QtdeTurmasProf', 'RelAlunProf', 'Ideb-2017'],
#       dtype='object', length=171)

# %% [markdown]
# ## Criação dos modelos
#
# **Serão feitas duas análises:** Apenas com as variáveis socioeconômicas e depois com o dataset completo
#
# Para cada uma serão criados modelos com todos os atributos e também com seleção de atributos, a fim de verificar o de maior acurácia

# %% [markdown]
# **-Primeira análise: variáveis socioeconômicas derivadas da prova SAEB**

# %%
#Foi retirada colunas do 'ID_PROVA_BRASIL', 'ID_REGIAO', 'ID_UF'
columns = dataset.columns[3:234]

columns
# Out:
# Index(['ID_MUNICIPIO', 'ID_AREA', 'ID_DEPENDENCIA_ADM', 'ID_LOCALIZACAO',
#        'TX_RESP_Q001_A', 'TX_RESP_Q001_B', 'TX_RESP_Q020_A', 'TX_RESP_Q020_B',
#        'TX_RESP_Q021_A', 'TX_RESP_Q021_B',
#        ...
#        'TX_RESP_Q003_B', 'TX_RESP_Q003_C', 'TX_RESP_Q003_D', 'TX_RESP_Q003_E',
#        'TX_RESP_Q003_F', 'TX_RESP_Q003_G', 'TX_RESP_Q003_H', 'TX_RESP_Q003_I',
#        'TX_RESP_Q003_J', 'TX_RESP_Q003_L'],
#       dtype='object', length=231)

# %%
X =  dataset[columns]
y = Ideb['classe-Ideb']

X
# Out:
#           ID_MUNICIPIO  ID_AREA  ID_DEPENDENCIA_ADM  ID_LOCALIZACAO  \
# 28012631       2800100        2                   2               1
# 28017846       2800308        1                   2               1
# 28017854       2800308        1                   2               1
# 28018400       2800308        1                   2               1
# 28018435       2800308        1                   2               1
# ...                ...      ...                 ...             ...
# 28009398       2807105        2                   2               1
# 28009487       2807105        2                   2               2
# 28014839       2807204        2                   2               1
# 28010132       2807402        2                   2               1
# 28028562       2807600        2                   2               1
#
#           TX_RESP_Q001_A  TX_RESP_Q001_B  TX_RESP_Q020_A  TX_RESP_Q020_B  \
# 28012631              12               6              15               4
# 28017846              21              20              37               4
# 28017854              39              62              93              10
# 28018400              36              36              71               2
# 28018435              56              79             124              14
# ...                  ...             ...             ...             ...
# 28009398             106             186             253              39
# 28009487              18              23              32              10
# 28014839              31              42              68               6
# 28010132              62              76             110              31
# 28028562              33              68              80              20
#
#           TX_RESP_Q021_A  TX_RESP_Q021_B  ...  TX_RESP_Q003_B  TX_RESP_Q003_C  \
# 28012631              16               3  ...               2               3
# 28017846              31              10  ...               4              10
# 28017854              77              25  ...               7               9
# 28018400              55              18  ...               6              10
# 28018435             101              37  ...              13              10
# ...                  ...             ...  ...             ...             ...
# 28009398             198              95  ...              28              37
# 28009487              31              11  ...               3               1
# 28014839              57              17  ...               8               5
# 28010132              92              49  ...               5              16
# 28028562              69              32  ...               4               4
#
#           TX_RESP_Q003_D  TX_RESP_Q003_E  TX_RESP_Q003_F  TX_RESP_Q003_G  \
# 28012631               1               1               0               0
# 28017846               2               7               4               1
# 28017854               4              10              13               5
# 28018400               8               8               4               4
# 28018435              14              21              11              10
# ...                  ...             ...             ...             ...
# 28009398              24              26              21              24
# 28009487               4               6               3               7
# 28014839               5              11               5               8
# 28010132              13              17               9              10
# 28028562              15              12              10               6
#
#           TX_RESP_Q003_H  TX_RESP_Q003_I  TX_RESP_Q003_J  TX_RESP_Q003_L
# 28012631               3               3               2               1
# 28017846               4               3               3               1
# 28017854              15              11               5              10
# 28018400               5               3               6               7
# 28018435              11              11               7              18
# ...                  ...             ...             ...             ...
# 28009398              25              18              22              29
# 28009487               2               1               4               4
# 28014839               6               5               8               5
# 28010132              13              12              15               6
# 28028562               6               8               9              12
#
# [76 rows x 231 columns]

# %% [markdown]
# **Seleção de Atributos:**  É um passo da fase de pré-processamento que tem a finalidade de selecionar o melhor subconjunto de atributos que pode substituir o conjunto de dados original.

# %%
#Explicar a escolha do método de seleção de atributos
def selecao_atributos(X, y, quant):
    select = SelectKBest(score_func=f_classif, k=quant)
    z = select.fit_transform(X, y)
    
    print("After selecting best 100 features:", z.shape) 
    
    filter = select.get_support(indices=True)
    features = array(X.columns)
    
    return X.iloc[:, filter]

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import sklearn.metrics as metrics

# %% [markdown]
# #### Pré-processamento das variáveis pessoais

# %%
def acuracia(resultados, classes):
    #resultados = cross_val_predict(modelo, textos, classes, cv=10)  
    return 'Acurácia do modelo: {} %'.format(metrics.accuracy_score(classes, resultados)*100)

# %% [markdown]
# **Normalização:** é mudar os valores das colunas numéricas no conjunto de dados para usar uma escala comum, sem distorcer as diferenças nos intervalos de valores nem perder informações.
#
# **Normalização MinMax:** Para cada recurso, o valor mínimo desse recurso é transformado em 0, o valor máximo é transformado em 1 e todos os outros valores são transformados em um decimal entre 0 e 1.

# %%
def minmax(data):
    scaler = MinMaxScaler()
    data_scaler = scaler.fit_transform(data)
    return data_scaler

# %%
def inicializar_modelos():
    naive = MultinomialNB()
    random = RandomForestClassifier(n_estimators=150)
    decision_tree = DecisionTreeClassifier()
    svm = SVC(kernel="linear")
    r_logistic = LogisticRegression()
    knn = KNeighborsClassifier(n_neighbors=3)
    return naive, random, decision_tree, svm, r_logistic, knn

# %% [markdown]
# **Divisão entre conjunto de treino e teste**

# %%
X_scaler = minmax(X)

X_train, X_test, y_train, y_test = train_test_split(X_scaler, y, random_state=50, test_size=0.2)

# %% [markdown]
# **Fase de Treinamento e Teste**

# %%
naive, random, decision_tree, svm, r_logistic, knn = inicializar_modelos()

# %%
naive.fit(X_train, y_train)
random.fit(X_train, y_train)
decision_tree.fit(X_train, y_train)
svm.fit(X_train, y_train)
r_logistic.fit(X_train, y_train)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
random_result = random.predict(X_test)
naive_result = naive.predict(X_test)
decision_result = decision_tree.predict(X_test)
svm_result = svm.predict(X_test)
logistic_result = r_logistic.predict(X_test)
knn_result = knn.predict(X_test)

print("Random forest: " + acuracia(random_result, y_test))
print("Naive Bayes: " + acuracia(naive_result, y_test))
print("Decision Tree: " + acuracia(decision_result, y_test))
print("SVM: " + acuracia(svm_result, y_test))
print("Logistic Regression: "+acuracia(logistic_result, y_test))
print("KNN: "+acuracia(knn_result, y_test))
# Out:
# Random forest: Acurácia do modelo: 81.25 %
# Naive Bayes: Acurácia do modelo: 68.75 %
# Decision Tree: Acurácia do modelo: 68.75 %
# SVM: Acurácia do modelo: 75.0 %
# Logistic Regression: Acurácia do modelo: 81.25 %
# KNN: Acurácia do modelo: 50.0 %

# %% [markdown]
# **-Primeira Análise: Aplicando Seleção de Atributos**

# %%
X_selection = selecao_atributos(X, y, 50)

X_selection
# Out:
# After selecting best 100 features: (76, 50)
# C:\Users\maril\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [150] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\maril\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
#           ID_AREA  ID_LOCALIZACAO  TX_RESP_Q020_B  TX_RESP_Q028_B  \
# 28012631        2               1               4               6
# 28017846        1               1               4               6
# 28017854        1               1              10               9
# 28018400        1               1               2              14
# 28018435        1               1              14              20
# ...           ...             ...             ...             ...
# 28009398        2               1              39              25
# 28009487        2               2              10               6
# 28014839        2               1               6               3
# 28010132        2               1              31              21
# 28028562        2               1              20              11
#
#           TX_RESP_Q043_A  TX_RESP_Q033_A  TX_RESP_Q042_C  TX_RESP_Q049_C  \
# 28012631               4               0               1               0
# 28017846               6               7               0               3
# 28017854              15              15               5               2
# 28018400               3              16               0               1
# 28018435              14               8               2               3
# ...                  ...             ...             ...             ...
# 28009398              15              33               4               2
# 28009487               2               6               0               0
# 28014839              15              13               1               3
# 28010132              27              16               2               2
# 28028562              16              11               3               2
#
#           TX_RESP_Q057_C  TX_RESP_Q039_D  ...  TX_RESP_Q019_A  TX_RESP_Q019_D  \
# 28012631               0               0  ...               1               0
# 28017846               3               0  ...               1               9
# 28017854              10               1  ...               3              17
# 28018400               1               0  ...               0              13
# 28018435               3               2  ...               2              22
# ...                  ...             ...  ...             ...             ...
# 28009398               2               4  ...              15              23
# 28009487               0               0  ...               4               4
# 28014839               4               0  ...               2              14
# 28010132               3               1  ...              14              14
# 28028562               3               3  ...               5               8
#
#           TX_RESP_Q019_F  TX_RESP_Q019_G  TX_RESP_Q023_E  TX_RESP_Q023_F  \
# 28012631               4               3               2               2
# 28017846               1               4               9               0
# 28017854               1              13              24               3
# 28018400               8               6              19               7
# 28018435              14              13              30               6
# ...                  ...             ...             ...             ...
# 28009398              15              21              24               5
# 28009487               1               4               2               0
# 28014839               5              10              10               2
# 28010132               7              21              15               2
# 28028562               3              12               3               0
#
#           TX_RESP_Q004_B  TX_RESP_Q004_C  TX_RESP_Q004_G  TX_RESP_Q004_H
# 28012631               0               9               0               0
# 28017846               1              12               0               0
# 28017854               2              22               5               6
# 28018400               5              34               0               0
# 28018435               6              40               6               5
# ...                  ...             ...             ...             ...
# 28009398               6              95              15              16
# 28009487               0              17               4               1
# 28014839               3              24               4               4
# 28010132               3              32              10              12
# 28028562               1              37               5               3
#
# [76 rows x 50 columns]

# %%
X_scaler = minmax(X_selection)

X_train, X_test, y_train, y_test = train_test_split(X_scaler, y, random_state=50, test_size=0.2)

# %% [markdown]
# **Fase de Treinamento e Teste**

# %%
naive, random, decision_tree, svm, r_logistic, knn = inicializar_modelos()

# %%
naive.fit(X_train, y_train)
random.fit(X_train, y_train)
decision_tree.fit(X_train, y_train)
svm.fit(X_train, y_train)
r_logistic.fit(X_train, y_train)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
random_result = random.predict(X_test)
naive_result = naive.predict(X_test)
decision_result = decision_tree.predict(X_test)
svm_result = svm.predict(X_test)
logistic_result = r_logistic.predict(X_test)
knn_result = knn.predict(X_test)

print("Random forest: " + acuracia(random_result, y_test))
print("Naive Bayes: " + acuracia(naive_result, y_test))
print("Decision Tree: " + acuracia(decision_result, y_test))
print("SVM: " + acuracia(svm_result, y_test))
print("Logistic Regression: "+acuracia(logistic_result, y_test))
print("KNN: "+acuracia(knn_result, y_test))
# Out:
# Random forest: Acurácia do modelo: 87.5 %
# Naive Bayes: Acurácia do modelo: 75.0 %
# Decision Tree: Acurácia do modelo: 62.5 %
# SVM: Acurácia do modelo: 81.25 %
# Logistic Regression: Acurácia do modelo: 87.5 %
# KNN: Acurácia do modelo: 75.0 %

# %% [markdown]
# #### -Segunda análise: Análise com o dataset completo

# %%
#Lembrar de tratar datas
X_completo = dataset.drop(['ID_PROVA_BRASIL', 'ID_REGIAO', 'ID_UF', 'DT_ANO_LETIVO_INICIO', 'DT_ANO_LETIVO_TERMINO', 'Ideb-2017'], axis=1)

X_completo
# Out:
#           ID_MUNICIPIO  ID_AREA  ID_DEPENDENCIA_ADM  ID_LOCALIZACAO  \
# 28012631       2800100        2                   2               1
# 28017846       2800308        1                   2               1
# 28017854       2800308        1                   2               1
# 28018400       2800308        1                   2               1
# 28018435       2800308        1                   2               1
# ...                ...      ...                 ...             ...
# 28009398       2807105        2                   2               1
# 28009487       2807105        2                   2               2
# 28014839       2807204        2                   2               1
# 28010132       2807402        2                   2               1
# 28028562       2807600        2                   2               1
#
#           TX_RESP_Q001_A  TX_RESP_Q001_B  TX_RESP_Q020_A  TX_RESP_Q020_B  \
# 28012631              12               6              15               4
# 28017846              21              20              37               4
# 28017854              39              62              93              10
# 28018400              36              36              71               2
# 28018435              56              79             124              14
# ...                  ...             ...             ...             ...
# 28009398             106             186             253              39
# 28009487              18              23              32              10
# 28014839              31              42              68               6
# 28010132              62              76             110              31
# 28028562              33              68              80              20
#
#           TX_RESP_Q021_A  TX_RESP_Q021_B  ...  QtdeDocentesAuxAssist  \
# 28012631              16               3  ...                      0
# 28017846              31              10  ...                      0
# 28017854              77              25  ...                      0
# 28018400              55              18  ...                      0
# 28018435             101              37  ...                      0
# ...                  ...             ...  ...                    ...
# 28009398             198              95  ...                      0
# 28009487              31              11  ...                      0
# 28014839              57              17  ...                      0
# 28010132              92              49  ...                      0
# 28028562              69              32  ...                      0
#
#           QtdeDocentesMonit  QtdeDocentesEfetivos  QtdeDocentesTempo  \
# 28012631                  0                     7                  1
# 28017846                  0                    22                  0
# 28017854                  0                    32                  0
# 28018400                  0                    34                  0
# 28018435                  0                    41                  0
# ...                     ...                   ...                ...
# 28009398                  0                    46                  5
# 28009487                  0                    12                  1
# 28014839                  1                    16                  0
# 28010132                  0                    27                  3
# 28028562                  0                    18                  4
#
#           QtdeDocentesTerceir  QtdeDocentesCLT  QtdeDocentesTotal  \
# 28012631                    0                0                  8
# 28017846                    0                0                 22
# 28017854                    0                0                 32
# 28018400                    0                0                 34
# 28018435                    0                0                 41
# ...                       ...              ...                ...
# 28009398                    0                0                 51
# 28009487                    0                0                 13
# 28014839                    0                1                 17
# 28010132                    0                0                 30
# 28028562                    0                0                 22
#
#           QtdeAlunosTotal  QtdeTurmasProf  RelAlunProf
# 28012631               22               8            2
# 28017846              121              22            5
# 28017854              301              32            9
# 28018400              383              34           11
# 28018435              476              41           11
# ...                   ...             ...          ...
# 28009398              611              51           11
# 28009487              176              13           13
# 28014839              198              17           11
# 28010132              486              30           16
# 28028562              175              22            7
#
# [76 rows x 399 columns]

# %%
X_transform = minmax(X_completo)

X_train, X_test, y_train, y_test = train_test_split(X_transform, y, random_state=50, test_size=0.2)

# %% [markdown]
# **Fase de Treinamento e Teste**

# %%
naive, random, decision_tree, svm, r_logistic, knn = inicializar_modelos()

# %%
naive.fit(X_train, y_train)
random.fit(X_train, y_train)
decision_tree.fit(X_train, y_train)
svm.fit(X_train, y_train)
r_logistic.fit(X_train, y_train)
knn.fit(X_train, y_train)
# Out:
# C:\Users\maril\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# KNeighborsClassifier(n_neighbors=3)

# %%
random_result = random.predict(X_test)
naive_result = naive.predict(X_test)
decision_result = decision_tree.predict(X_test)
svm_result = svm.predict(X_test)
logistic_result = r_logistic.predict(X_test)
knn_result = knn.predict(X_test)

print("Random forest: " + acuracia(random_result, y_test))
print("Naive Bayes: " + acuracia(naive_result, y_test))
print("Decision Tree: " + acuracia(decision_result, y_test))
print("SVM: " + acuracia(svm_result, y_test))
print("Logistic Regression: "+acuracia(logistic_result, y_test))
print("KNN: "+acuracia(knn_result, y_test))
# Out:
# Random forest: Acurácia do modelo: 68.75 %
# Naive Bayes: Acurácia do modelo: 75.0 %
# Decision Tree: Acurácia do modelo: 75.0 %
# SVM: Acurácia do modelo: 56.25 %
# Logistic Regression: Acurácia do modelo: 56.25 %
# KNN: Acurácia do modelo: 75.0 %

# %% [markdown]
# **-Segunda Análise: Aplicando Seleção de Atributos**

# %%
X_selection = selecao_atributos(X_completo, y, 50)

X_selection
# Out:
# After selecting best 100 features: (76, 50)
# C:\Users\maril\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [150 231 233 234 237 245 246 247 248 249 250 251 256 259 260 261 262 263
#  264 270 271 272 273 282 286 287 289 290 301 305 320 336 339 345 347 348
#  350 351 352 353 354 355 358 359 362 364 365 366 367 368 369 370 371 375
#  376 377 379 381 382 389 393] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\maril\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
#           ID_AREA  ID_LOCALIZACAO  TX_RESP_Q020_B  TX_RESP_Q043_A  \
# 28012631        2               1               4               4
# 28017846        1               1               4               6
# 28017854        1               1              10              15
# 28018400        1               1               2               3
# 28018435        1               1              14              14
# ...           ...             ...             ...             ...
# 28009398        2               1              39              15
# 28009487        2               2              10               2
# 28014839        2               1               6              15
# 28010132        2               1              31              27
# 28028562        2               1              20              16
#
#           TX_RESP_Q042_C  TX_RESP_Q039_D  TX_RESP_Q060_D  TX_RESP_Q005_A  \
# 28012631               1               0               0               1
# 28017846               0               0               0               0
# 28017854               5               1               1               5
# 28018400               0               0               1               4
# 28018435               2               2               0               2
# ...                  ...             ...             ...             ...
# 28009398               4               4               0              10
# 28009487               0               0               0               0
# 28014839               1               0               0               2
# 28010132               2               1              31               6
# 28028562               3               3              10               5
#
#           TX_RESP_Q005_E  TX_RESP_Q006_E  ...  NU_SALAS_EXISTENTES  \
# 28012631               0               0  ...                    4
# 28017846               0               0  ...                   16
# 28017854               1               0  ...                   20
# 28018400               1               0  ...                   17
# 28018435               2               1  ...                   13
# ...                  ...             ...  ...                  ...
# 28009398               3               0  ...                   14
# 28009487               0               0  ...                    6
# 28014839               0               0  ...                   11
# 28010132               1               0  ...                   11
# 28028562               0               0  ...                    9
#
#           IN_EQUIP_IMPRESSORA_MULT  IN_EQUIP_FAX  NU_EQUIP_IMPRESSORA_MULT  \
# 28012631                         1             0                         1
# 28017846                         1             0                         2
# 28017854                         0             0                         0
# 28018400                         1             1                         1
# 28018435                         0             0                         0
# ...                            ...           ...                       ...
# 28009398                         0             0                         0
# 28009487                         1             0                         2
# 28014839                         1             0                         3
# 28010132                         1             0                         2
# 28028562                         1             0                         2
#
#           NU_EQUIP_FAX  NU_COMPUTADOR  NU_COMP_ADMINISTRATIVO  \
# 28012631             0             12                       2
# 28017846             0              5                       5
# 28017854             0             25                       3
# 28018400             1             30                       5
# 28018435             0             34                       8
# ...                ...            ...                     ...
# 28009398             0             33                       4
# 28009487             0             12                       4
# 28014839             0             56                       3
# 28010132             0              8                       2
# 28028562             0             21                       7
#
#           NU_FUNCIONARIOS  IN_COMUM_FUND_AF  QtdeDocentesMest
# 28012631               17                 0                 1
# 28017846               55                 1                 2
# 28017854               81                 1                 2
# 28018400               75                 1                 4
# 28018435               86                 1                 5
# ...                   ...               ...               ...
# 28009398               90                 0                 3
# 28009487               35                 1                 1
# 28014839               55                 1                 0
# 28010132               53                 1                 0
# 28028562               44                 1                 2
#
# [76 rows x 50 columns]

# %%
X_transform = minmax(X_selection)

X_train, X_test, y_train, y_test = train_test_split(X_transform, y, random_state=50, test_size=0.2)

# %% [markdown]
# **Fase de Treinamento e Teste**

# %%
naive, random, decision_tree, svm, r_logistic, knn = inicializar_modelos()

# %%
naive.fit(X_train, y_train)
random.fit(X_train, y_train)
decision_tree.fit(X_train, y_train)
svm.fit(X_train, y_train)
r_logistic.fit(X_train, y_train)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
random_result = random.predict(X_test)
naive_result = naive.predict(X_test)
decision_result = decision_tree.predict(X_test)
svm_result = svm.predict(X_test)
logistic_result = r_logistic.predict(X_test)
knn_result = knn.predict(X_test)

print("Random forest: " + acuracia(random_result, y_test))
print("Naive Bayes: " + acuracia(naive_result, y_test))
print("Decision Tree: " + acuracia(decision_result, y_test))
print("SVM: " + acuracia(svm_result, y_test))
print("Logistic Regression: "+acuracia(logistic_result, y_test))
print("KNN: "+acuracia(knn_result, y_test))
# Out:
# Random forest: Acurácia do modelo: 75.0 %
# Naive Bayes: Acurácia do modelo: 81.25 %
# Decision Tree: Acurácia do modelo: 68.75 %
# SVM: Acurácia do modelo: 81.25 %
# Logistic Regression: Acurácia do modelo: 93.75 %
# KNN: Acurácia do modelo: 50.0 %

# %%
X_selection.columns
# Out:
# Index(['ID_AREA', 'ID_LOCALIZACAO', 'TX_RESP_Q020_B', 'TX_RESP_Q043_A',
#        'TX_RESP_Q042_C', 'TX_RESP_Q039_D', 'TX_RESP_Q060_D', 'TX_RESP_Q005_A',
#        'TX_RESP_Q005_E', 'TX_RESP_Q006_E', 'TX_RESP_Q009_E', 'TX_RESP_Q010_E',
#        'TX_RESP_Q012_B', 'TX_RESP_Q013_B', 'TX_RESP_Q013_C', 'TX_RESP_Q015_A',
#        'TX_RESP_Q036_A', 'TX_RESP_Q036_E', 'TX_RESP_Q002_E', 'TX_RESP_Q016_A',
#        'TX_RESP_Q019_A', 'TX_RESP_Q019_G', 'TX_RESP_Q023_E', 'TX_RESP_Q023_F',
#        'TX_RESP_Q004_B', 'TX_RESP_Q004_G', 'TX_RESP_Q004_H',
#        'CO_ORGAO_REGIONAL', 'CO_MESORREGIAO', 'TP_LOCALIZACAO',
#        'TP_OCUPACAO_PREDIO_ESCOLAR', 'IN_PREDIO_COMPARTILHADO',
#        'IN_ESGOTO_REDE_PUBLICA', 'IN_SALA_DIRETORIA',
#        'IN_LABORATORIO_INFORMATICA', 'IN_QUADRA_ESPORTES_COBERTA',
#        'IN_QUADRA_ESPORTES', 'IN_BIBLIOTECA', 'IN_BIBLIOTECA_SALA_LEITURA',
#        'IN_ALMOXARIFADO', 'NU_SALAS_EXISTENTES', 'IN_EQUIP_IMPRESSORA_MULT',
#        'IN_EQUIP_FAX', 'NU_EQUIP_IMPRESSORA_MULT', 'NU_EQUIP_FAX',
#        'NU_COMPUTADOR', 'NU_COMP_ADMINISTRATIVO', 'NU_FUNCIONARIOS',
#        'IN_COMUM_FUND_AF', 'QtdeDocentesMest'],
#       dtype='object')

# %%
df_resultado = pd.DataFrame()
df_resultado = y_test.to_frame()
df_resultado['previsto'] = logistic_result

dados_para_exportar = df_resultado.loc[df_resultado['classe-Ideb'] == df_resultado['previsto']].join(dataset[X_selection.columns], how="inner")

# %%
dados_para_exportar.to_csv('C:/Users/maril/Documents/ufs/TCC e Pesquisa IDEB/resultado_melhor_analise.csv')
# Out:
#               classe-Ideb         previsto  ID_AREA  ID_LOCALIZACAO  \
# 28006720   acima da média   acima da média        2               1
# 28013921  abaixo da média  abaixo da média        2               1
# 28025903  abaixo da média  abaixo da média        2               1
# 28022033   acima da média   acima da média        2               1
# 28004809   acima da média   acima da média        2               1
# 28001400  abaixo da média  abaixo da média        2               1
# 28018516   acima da média   acima da média        1               1
# 28000951   acima da média   acima da média        2               1
# 28006739  abaixo da média  abaixo da média        2               1
# 28013700  abaixo da média  abaixo da média        2               1
# 28003047  abaixo da média  abaixo da média        2               2
# 28006330  abaixo da média  abaixo da média        2               1
# 28016106  abaixo da média  abaixo da média        2               1
# 28016890  abaixo da média  abaixo da média        2               1
# 28008421   acima da média   acima da média        2               1
#
#           TX_RESP_Q020_B  TX_RESP_Q043_A  TX_RESP_Q042_C  TX_RESP_Q039_D  \
# 28006720               5               3               0               0
# 28013921              13              16               0               0
# 28025903              19               5               5               0
# 28022033              11               5               1               1
# 28004809               7               4               1               0
# 28001400              13              20               4               1
# 28018516               0               4               1               1
# 28000951              14               7               0               0
# 28006739              31              17               5               2
# 28013700              22              18               3               1
# 28003047               6               9               1               2
# 28006330              10               9               3               1
# 28016106               6               8               0               0
# 28016890               4               6               1               0
# 28008421              12               9               0               0
#
#           TX_RESP_Q060_D  TX_RESP_Q005_A  ...  NU_SALAS_EXISTENTES  \
# 28006720               0               0  ...                   10
# 28013921               3               1  ...                   11
# 28025903              10               5  ...                    9
# 28022033               0               4  ...                    9
# 28004809               0               0  ...                    9
# 28001400               4               6  ...                    9
# 28018516               0               5  ...                   14
# 28000951               1               3  ...                    9
# 28006739              75               6  ...                   11
# 28013700              12               7  ...                   10
# 28003047              11               1  ...                    4
# 28006330               6               0  ...                   14
# 28016106               1               0  ...                    5
# 28016890               2               4  ...                   11
# 28008421               8               3  ...                    9
#
#           IN_EQUIP_IMPRESSORA_MULT  IN_EQUIP_FAX  NU_EQUIP_IMPRESSORA_MULT  \
# 28006720                         1             0                         3
# 28013921                         1             1                         2
# 28025903                         1             0                         1
# 28022033                         1             1                         2
# 28004809                         1             0                         1
# 28001400                         1             1                         4
# 28018516                         1             1                         2
# 28000951                         1             1                         2
# 28006739                         1             1                         3
# 28013700                         1             0                         1
# 28003047                         1             0                         1
# 28006330                         1             0                         1
# 28016106                         1             1                         1
# 28016890                         1             1                         2
# 28008421                         1             0                         1
#
#           NU_EQUIP_FAX  NU_COMPUTADOR  NU_COMP_ADMINISTRATIVO  \
# 28006720             0             14                       3
# 28013921             1             16                       2
# 28025903             0             20                       1
# 28022033             1             42                       4
# 28004809             0             16                       4
# 28001400             1             30                       5
# 28018516             1             30                       8
# 28000951             1             30                       4
# 28006739             1             27                       7
# 28013700             0             31                       9
# 28003047             0             12                       3
# 28006330             0             13                       5
# 28016106             1             18                       1
# 28016890             1              8                       3
# 28008421             0             24                       4
#
#           NU_FUNCIONARIOS  IN_COMUM_FUND_AF  QtdeDocentesMest
# 28006720               67                 1                 1
# 28013921               43                 1                 1
# 28025903               41                 1                 1
# 28022033               71                 1                 4
# 28004809               39                 1                 0
# 28001400               56                 1                 4
# 28018516               86                 1                 3
# 28000951               37                 1                 2
# 28006739               52                 1                 1
# 28013700               64                 1                 0
# 28003047               33                 1                 0
# 28006330               73                 1                 0
# 28016106               33                 0                 1
# 28016890               53                 1                 5
# 28008421               58                 1                 0
#
# [15 rows x 52 columns]

# %% [markdown]
# **-Terceira análise: variáveis das escolas e professores**

# %%
columns_escolas = dataset.columns[235:404]

X_escolas = dataset[columns_escolas]

X_transform = minmax(X_escolas)

X_train, X_test, y_train, y_test = train_test_split(X_transform, y, random_state=50, test_size=0.2)

# %% [markdown]
# **Fase de Teste e Treinamento**

# %%
naive, random, decision_tree, svm, r_logistic, knn = inicializar_modelos()

# %%
naive.fit(X_train, y_train)
random.fit(X_train, y_train)
decision_tree.fit(X_train, y_train)
svm.fit(X_train, y_train)
r_logistic.fit(X_train, y_train)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
random_result = random.predict(X_test)
naive_result = naive.predict(X_test)
decision_result = decision_tree.predict(X_test)
svm_result = svm.predict(X_test)
logistic_result = r_logistic.predict(X_test)
knn_result = knn.predict(X_test)

print("Random forest: " + acuracia(random_result, y_test))
print("Naive Bayes: " + acuracia(naive_result, y_test))
print("Decision Tree: " + acuracia(decision_result, y_test))
print("SVM: " + acuracia(svm_result, y_test))
print("Logistic Regression: "+acuracia(logistic_result, y_test))
print("KNN: "+acuracia(knn_result, y_test))
# Out:
# Random forest: Acurácia do modelo: 56.25 %
# Naive Bayes: Acurácia do modelo: 50.0 %
# Decision Tree: Acurácia do modelo: 25.0 %
# SVM: Acurácia do modelo: 37.5 %
# Logistic Regression: Acurácia do modelo: 37.5 %
# KNN: Acurácia do modelo: 81.25 %

# %% [markdown]
# **-Terceira análise: Aplicando seleção de atributos**

# %%
X_selection = selecao_atributos(X_escolas , y, 50)

X_selection
# Out:
# After selecting best 100 features: (76, 50)
# C:\Users\maril\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:114: UserWarning: Features [  1   4   7  15  16  17  18  19  20  21  26  29  30  31  32  33  34  40
#   41  42  43  52  56  57  59  60  71  75  90 106 109 115 117 118 120 121
#  122 123 124 125 128 129 132 134 135 136 137 138 139 140 141 145 146 147
#  149 151 152 159 163] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# C:\Users\maril\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
#           CO_ORGAO_REGIONAL  DT_ANO_LETIVO_INICIO  DT_ANO_LETIVO_TERMINO  \
# 28012631                6.0   1486944000000000000    1513900800000000000
# 28017846                0.0   1494201600000000000    1519776000000000000
# 28017854                0.0   1491782400000000000    1519344000000000000
# 28018400                0.0   1492387200000000000    1519862400000000000
# 28018435                0.0   1489363200000000000    1515196800000000000
# ...                     ...                   ...                    ...
# 28009398                2.0   1493683200000000000    1518739200000000000
# 28009487                2.0   1490745600000000000    1516838400000000000
# 28014839                5.0   1488412800000000000    1517011200000000000
# 28010132                2.0   1488758400000000000    1516320000000000000
# 28028562                1.0   1487548800000000000    1516665600000000000
#
#           CO_MESORREGIAO  TP_LOCALIZACAO  TP_REGULAMENTACAO  \
# 28012631            2803               1                  1
# 28017846            2803               1                  1
# 28017854            2803               1                  1
# 28018400            2803               1                  1
# 28018435            2803               1                  1
# ...                  ...             ...                ...
# 28009398            2802               1                  1
# 28009487            2802               2                  1
# 28014839            2803               1                  1
# 28010132            2802               1                  1
# 28028562            2803               1                  1
#
#           TP_OCUPACAO_PREDIO_ESCOLAR  IN_LOCAL_FUNC_SALAS_OUTRA_ESC  \
# 28012631                         1.0                              0
# 28017846                         1.0                              0
# 28017854                         1.0                              0
# 28018400                         1.0                              0
# 28018435                         1.0                              0
# ...                              ...                            ...
# 28009398                         1.0                              0
# 28009487                         1.0                              0
# 28014839                         1.0                              0
# 28010132                         1.0                              0
# 28028562                         1.0                              0
#
#           IN_PREDIO_COMPARTILHADO  IN_ESGOTO_REDE_PUBLICA  ...  \
# 28012631                      0.0                       1  ...
# 28017846                      0.0                       1  ...
# 28017854                      0.0                       1  ...
# 28018400                      0.0                       1  ...
# 28018435                      0.0                       1  ...
# ...                           ...                     ...  ...
# 28009398                      0.0                       1  ...
# 28009487                      0.0                       1  ...
# 28014839                      0.0                       0  ...
# 28010132                      0.0                       1  ...
# 28028562                      0.0                       0  ...
#
#           IN_COMUM_FUND_AF  IN_COMUM_EJA_MEDIO  QtdeDocentesComLicenciatura  \
# 28012631                 0                   1                            8
# 28017846                 1                   0                           22
# 28017854                 1                   0                           28
# 28018400                 1                   0                           30
# 28018435                 1                   0                           37
# ...                    ...                 ...                          ...
# 28009398                 0                   0                           46
# 28009487                 1                   0                           13
# 28014839                 1                   1                           16
# 28010132                 1                   0                           30
# 28028562                 1                   1                           21
#
#           QtdeDocentesMest  QtdeDocentesDout  QtdeDocentes  \
# 28012631                 1                 0             8
# 28017846                 2                 0            22
# 28017854                 2                 0            32
# 28018400                 4                 0            34
# 28018435                 5                 0            41
# ...                    ...               ...           ...
# 28009398                 3                 0            51
# 28009487                 1                 0            13
# 28014839                 0                 1            16
# 28010132                 0                 0            30
# 28028562                 2                 0            22
#
#           QtdeDocentesEfetivos  QtdeDocentesTotal  QtdeTurmasProf  RelAlunProf
# 28012631                     7                  8               8            2
# 28017846                    22                 22              22            5
# 28017854                    32                 32              32            9
# 28018400                    34                 34              34           11
# 28018435                    41                 41              41           11
# ...                        ...                ...             ...          ...
# 28009398                    46                 51              51           11
# 28009487                    12                 13              13           13
# 28014839                    16                 17              17           11
# 28010132                    27                 30              30           16
# 28028562                    18                 22              22            7
#
# [76 rows x 50 columns]

# %%
X_transform = minmax(X_selection)

X_train, X_test, y_train, y_test = train_test_split(X_transform, y, random_state=50, test_size=0.2)

# %% [markdown]
# **Fase de Treinamento e Teste**

# %%
naive, random, decision_tree, svm, r_logistic, knn = inicializar_modelos()

# %%
naive.fit(X_train, y_train)
random.fit(X_train, y_train)
decision_tree.fit(X_train, y_train)
svm.fit(X_train, y_train)
r_logistic.fit(X_train, y_train)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
random_result = random.predict(X_test)
naive_result = naive.predict(X_test)
decision_result = decision_tree.predict(X_test)
svm_result = svm.predict(X_test)
logistic_result = r_logistic.predict(X_test)
knn_result = knn.predict(X_test)

print("Random forest: " + acuracia(random_result, y_test))
print("Naive Bayes: " + acuracia(naive_result, y_test))
print("Decision Tree: " + acuracia(decision_result, y_test))
print("SVM: " + acuracia(svm_result, y_test))
print("Logistic Regression: "+acuracia(logistic_result, y_test))
print("KNN: "+acuracia(knn_result, y_test))
# Out:
# Random forest: Acurácia do modelo: 50.0 %
# Naive Bayes: Acurácia do modelo: 56.25 %
# Decision Tree: Acurácia do modelo: 56.25 %
# SVM: Acurácia do modelo: 50.0 %
# Logistic Regression: Acurácia do modelo: 50.0 %
# KNN: Acurácia do modelo: 50.0 %
